# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
google_api_key = os.getenv('GOOGLE_API_KEY')

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:8]}")
else:
    print("Google API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# Google API Key exists and begins AQ.Ab8RN

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

GoogleAI = OpenAI(base_url="https://generativelanguage.googleapis.com/v1beta/openai/", api_key=google_api_key)

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is the capital of Italy?"}]

# %%
messages
# Out:
# [{'role': 'user', 'content': 'What is the capital of Italy?'}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

#response = openai.chat.completions.create(model="gpt-5.4-nano", messages=messages)
#print(response.choices[0].message.content)
response = GoogleAI.chat.completions.create(model="gemma-4-31b-it", messages=messages)
print(response.choices[0].message.content)
# Out:
# <thought>*   Goal: Propose a hard, challenging question to assess someone's IQ.
#     *   Constraint: Respond *only* with the question.
#
#     *   IQ questions usually involve pattern recognition, logical reasoning, spatial intelligence, or linguistic analogies.
#     *   Riddles are often confused with IQ tests, but true IQ items focus on fluid intelligence (the ability to solve new problems without prior knowledge).
#     *   A classic "hard" problem is a sequence or a complex logical puzzle.
#
#     *   *Option 1 (Sequence):* 2, 3, 5, 7, 11... (Too easy).
#     *   *Option 2 (Lateral Thinking):* A man is looking at a portrait... (More of a riddle).
#     *   *Option 3 (Abstract Reasoning):* If all Bloops are Blips and some Blips are Blops, are all Bloops necessarily Blops? (Syllogism, moderately hard).
#     *   *Option 4 (Complex Logic/Pattern):* A problem involving a multi-step deduction or a sequence based on a non-obvious rule.
#
#     *   Let's go with a high-level logical deduction puzzle or a complex pattern.
#     *   Actually, a "Raven's Progressive Matrices" style question is the gold standard, but that requires an image. Since I need text, I should use a complex verbal analogy or a rigorous logical sequence.
#
#     *   *Drafting a logical challenge:*
#         "If five machines take five minutes to make five widgets, how long would it take one hundred machines to make one hundred widgets?" (Too common/easy).
#
#     *   *Drafting a complex sequence:*
#         "What is the next number in the sequence: 1, 11, 21, 1211, 111221, ...?" (The look-and-say sequence. Challenging, but a known puzzle).
#
#     *   *Drafting a formal logic problem:*
#         "Three gods A, B, and C are called, in no particular order, True, False, and Random. True always speaks truly, False always speaks falsely, but whether Random speaks truly or falsely is a completely random matter. Your task is to determine the identities of A, B, and C by asking three yes-no questions; each question must be put to exactly one god. The gods understand English, but will answer all questions in their own language, in which the words for yes and no are 'da' and 'ja', in some order. You do not know which word means which. What are the three questions?" (The "Hardest Logic Puzzle Ever").
#
#     *   The "Hardest Logic Puzzle Ever" is a classic for assessing high-level cognitive processing and deductive reasoning.
#
#     *   Constraint: Respond *only* with the question.
#
#     *   *Wait, is there something more concise?*
#         Maybe a complex analogy.
#         "A is to B as C is to D..."
#         No, the "Hardest Logic Puzzle" is a better benchmark for "hard/challenging."
#
#     *   Let's try a more compact but very difficult logic problem to ensure it feels like a "question" and not a "prompt for a project."
#
#     *   *Alternative:* A sequence problem.
#         "Find the next number in the sequence: 7, 26, 63, 124, 215, ..." (Pattern is $n^3 - 1$). Maybe too easy.
#
#     *   *Alternative:* "If a clock strikes thirteen, what time is it?" (Too riddle-like).
#
#     *   Let's use the "Hardest Logic Puzzle Ever" phrasing. It's the gold standard for "challenging logic."
#
#     *   *Refining the text:*
#         "Three gods A, B, and C are called, in no particular order, True, False, and Random. True always speaks truly, False always speaks falsely, but whether Random speaks truly or falsely is a completely random matter. Your task is to determine the identities of A, B, and C by asking three yes-no questions; each question must be put to exactly one god. The gods understand English, but will answer all questions in their own language, in which the words for yes and no are 'da' and 'ja', in some order. You do not know which word means which. What three questions would you ask?"
#
#     *   Is this an IQ question? It measures fluid intelligence, working memory, and logical deduction.
#
#     *   Wait, let me try one that is more "abstract/pattern" based for a traditional IQ feel.
#         "If 1=5, 2=25, 3=125, 4=625, then 5=?" (Trick question, answer is 1). Not really an IQ test, just a trick.
#
#     *   Let's go with the "Three Gods" puzzle.
#
#     *   *Actually*, let's go with a highly complex syllogism/logic puzzle that tests deduction.
#
#     *   *Revised choice:*
#         "You are presented with three boxes: one contains only apples, one contains only oranges, and one contains both apples and oranges. Every box is labeled incorrectly. You are allowed to pick one fruit from one box. How can you determine the contents of all three boxes?"
#
#     *   Wait, the prompt asks for a "hard, challenging question." The three boxes is a medium-difficulty logic puzzle.
#
#     *   Let's go back to the "Hardest Logic Puzzle Ever."
#
#     *   *Final Check:* Response only with the question.
#
#     *   *Text:* Three gods A, B, and C are called, in no particular order, True, False, and Random. True always speaks truly, False always speaks falsely, but whether Random speaks truly or falsely is a completely random matter. Your task is to determine the identities of A, B, and C by asking three yes-no questions; each question must be put to exactly one god. The gods understand English, but will answer all questions in their own language, in which the words for yes and no are 'da' and 'ja', in some order. You do not know which word means which. What three questions would you ask to identify each god?</thought>Three gods A, B, and C are called, in no particular order, True, False, and Random. True always speaks truly, False always speaks falsely, but whether Random speaks truly or falsely is a completely random matter. Your task is to determine the identities of A, B, and C by asking three yes-no questions; each question must be put to exactly one god. The gods understand English, but will answer all questions in their own language, in which the words for yes and no are 'da' and 'ja', in some order. You do not know which word means which. What three questions would you ask to identify each god?

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = GoogleAI.chat.completions.create(model="gemma-4-31b-it", messages=messages)
question = response.choices[0].message.content
print(question)
# Out:
# <thought>*   Goal: Propose a hard, challenging question to assess someone's IQ.
#     *   Constraint: Respond *only* with the question.
#
#     *   IQ tests typically measure pattern recognition, logical reasoning, spatial awareness, or mathematical ability.
#     *   Direct knowledge questions (trivia) aren't IQ indicators.
#     *   Logic puzzles, sequence completion, or abstract reasoning problems are best.
#
#     *   *Option 1 (Mathematical/Logical):* A complex probability problem.
#     *   *Option 2 (Pattern Recognition):* A word sequence with a hidden rule.
#     *   *Option 3 (Lateral Thinking/Logic):* A riddle that requires deductive reasoning.
#     *   *Option 4 (Abstract Reasoning):* A complex conditional logic puzzle.
#
#     *   *Draft 1 (Too simple):* "If all A are B, and some B are C, are some A necessarily C?" (Too easy).
#     *   *Draft 2 (Too trivia-based):* "What is the square root of 1764?" (Just a math test).
#     *   *Draft 3 (Logical Sequence):* "What number comes next in the sequence: 1, 11, 21, 1211, 111221, ...?" (Classic "look-and-say" sequence, but common).
#     *   *Draft 4 (Complex Logical Deduction):* A scenario involving truth-tellers and liars with a twist.
#
#     *   Let's go with a high-level pattern recognition/logical synthesis question.
#     *   Alternatively, a classic "hard" logic puzzle.
#
#     *   *Refined Idea:* A sequence that requires identifying a multi-step mathematical rule or a complex relationship.
#     *   *Actually, let's use a sophisticated logic puzzle involving self-reference or complex deduction.*
#
#     *   *Selected Question:* A variation of a hard logical deduction problem.
#     *   *Wait, let's try a pattern sequence that is non-trivial.*
#     *   Sequence: 2, 3, 10, 15, 26, 35, 50... what is the next number? (Squares +/- 1). Too easy.
#
#     *   Let's try a "meta-puzzle".
#     *   "If a clock strikes thirteen, what time is it?" (Too much like a riddle).
#
#     *   Let's go for a high-difficulty logical reasoning problem.
#     *   "Three gods A, B, and C are called, in no particular order, True, False, and Random. True always speaks truly, False always speaks falsely, but whether Random speaks truly or falsely is a completely random matter. Your task is to determine the identities of A, B, and C by asking three yes-no questions; each question must be put to exactly one god. The gods understand English, but will answer all questions in their own language, in which the words for yes and no are 'da' and 'ja', in some order. You do not know which word means which. What three questions do you ask?"
#     *   (This is "The Hardest Logic Puzzle Ever").
#
#     *   Does it assess IQ (specifically logic, synthesis, and deduction)? Yes.
#     *   Is it hard/challenging? Yes.
#     *   Is the response *only* the question? Yes.</thought>Three gods A, B, and C are called, in no particular order, True, False, and Random. True always speaks truly, False always speaks falsely, but whether Random speaks truly or falsely is a completely random matter. Your task is to determine the identities of A, B, and C by asking three yes-no questions; each question must be put to exactly one god. The gods understand English, but will answer all questions in their own language, in which the words for yes and no are "da" and "ja", in some order. You do not know which word means which. What three questions do you ask?

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages
# Out:
# [{'role': 'user',
#   'content': '<thought>*   Goal: Propose a hard, challenging question to assess someone\'s IQ.\n    *   Constraint: Respond *only* with the question.\n\n    *   IQ tests typically measure pattern recognition, logical reasoning, spatial awareness, or mathematical ability.\n    *   Direct knowledge questions (trivia) aren\'t IQ indicators.\n    *   Logic puzzles, sequence completion, or abstract reasoning problems are best.\n\n    *   *Option 1 (Mathematical/Logical):* A complex probability problem.\n    *   *Option 2 (Pattern Recognition):* A word sequence with a hidden rule.\n    *   *Option 3 (Lateral Thinking/Logic):* A riddle that requires deductive reasoning.\n    *   *Option 4 (Abstract Reasoning):* A complex conditional logic puzzle.\n\n    *   *Draft 1 (Too simple):* "If all A are B, and some B are C, are some A necessarily C?" (Too easy).\n    *   *Draft 2 (Too trivia-based):* "What is the square root of 1764?" (Just a math test).\n    *   *Draft 3 (Logical Sequence):* "What number comes next in the sequence: 1, 11, 21, 1211, 111221, ...?" (Classic "look-and-say" sequence, but common).\n    *   *Draft 4 (Complex Logical Deduction):* A scenario involving truth-tellers and liars with a twist.\n\n    *   Let\'s go with a high-level pattern recognition/logical synthesis question.\n    *   Alternatively, a classic "hard" logic puzzle.\n\n    *   *Refined Idea:* A sequence that requires identifying a multi-step mathematical rule or a complex relationship.\n    *   *Actually, let\'s use a sophisticated logic puzzle involving self-reference or complex deduction.*\n\n    *   *Selected Question:* A variation of a hard logical deduction problem.\n    *   *Wait, let\'s try a pattern sequence that is non-trivial.*\n    *   Sequence: 2, 3, 10, 15, 26, 35, 50... what is the next number? (Squares +/- 1). Too easy.\n\n    *   Let\'s try a "meta-puzzle".\n    *   "If a clock strikes thirteen, what time is it?" (Too much like a riddle).\n\n    *   Let\'s go for a high-difficulty logical reasoning problem.\n    *   "Three gods A, B, and C are called, in no particular order, True, False, and Random. True always speaks truly, False always speaks falsely, but whether Random speaks truly or falsely is a completely random matter. Your task is to determine the identities of A, B, and C by asking three yes-no questions; each question must be put to exactly one god. The gods understand English, but will answer all questions in their own language, in which the words for yes and no are \'da\' and \'ja\', in some order. You do not know which word means which. What three questions do you ask?"\n    *   (This is "The Hardest Logic Puzzle Ever").\n\n    *   Does it assess IQ (specifically logic, synthesis, and deduction)? Yes.\n    *   Is it hard/challenging? Yes.\n    *   Is the response *only* the question? Yes.</thought>Three gods A, B, and C are called, in no particular order, True, False, and Random. True always speaks truly, False always speaks falsely, but whether Random speaks truly or falsely is a completely random matter. Your task is to determine the identities of A, B, and C by asking three yes-no questions; each question must be put to exactly one god. The gods understand English, but will answer all questions in their own language, in which the words for yes and no are "da" and "ja", in some order. You do not know which word means which. What three questions do you ask?'}]

# %%
# Ask the model to answer the hard question

response = GoogleAI.chat.completions.create(model="gemma-4-31b-it", messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# Three gods A, B, and C are called, in no particular order, True, False, and Random. True always speaks truly, False always speaks falsely, but whether Random speaks truly or falsely is a completely random matter. Your task is to determine the identities of A, B, and C by asking three yes-no questions; each question must be put to exactly one god. The gods understand English, but will answer all questions in their own language, in which the words for yes and no are "da" and "ja", in some order. You do not know which word means which. What three questions do you ask?

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Three gods A, B, and C are called, in no particular order, True, False, and Random. True always speaks truly, False always speaks falsely, but whether Random speaks truly or falsely is a completely random matter. Your task is to determine the identities of A, B, and C by asking three yes-no questions; each question must be put to exactly one god. The gods understand English, but will answer all questions in their own language, in which the words for yes and no are "da" and "ja", in some order. You do not know which word means which. What three questions do you ask?

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)
# Out:
# Here is a question:
# <thought>*   Goal: Propose a hard, challenging question to assess someone's IQ.
#     *   Constraint: Respond *only* with the question.
#
#     *   IQ tests typically measure pattern recognition, logical reasoning, spatial awareness, or mathematical ability.
#     *   Direct knowledge questions (trivia) aren't IQ indicators.
#     *   Logic puzzles, sequence completion, or abstract reasoning problems are best.
#
#     *   *Option 1 (Mathematical/Logical):* A complex probability problem.
#     *   *Option 2 (Pattern Recognition):* A word sequence with a hidden rule.
#     *   *Option 3 (Lateral Thinking/Logic):* A riddle that requires deductive reasoning.
#     *   *Option 4 (Abstract Reasoning):* A complex conditional logic puzzle.
#
#     *   *Draft 1 (Too simple):* "If all A are B, and some B are C, are some A necessarily C?" (Too easy).
#     *   *Draft 2 (Too trivia-based):* "What is the square root of 1764?" (Just a math test).
#     *   *Draft 3 (Logical Sequence):* "What number comes next in the sequence: 1, 11, 21, 1211, 111221, ...?" (Classic "look-and-say" sequence, but common).
#     *   *Draft 4 (Complex Logical Deduction):* A scenario involving truth-tellers and liars with a twist.
#
#     *   Let's go with a high-level pattern recognition/logical synthesis question.
#     *   Alternatively, a classic "hard" logic puzzle.
#
#     *   *Refined Idea:* A sequence that requires identifying a multi-step mathematical rule or a complex relationship.
#     *   *Actually, let's use a sophisticated logic puzzle involving self-reference or complex deduction.*
#
#     *   *Selected Question:* A variation of a hard logical deduction problem.
#     *   *Wait, let's try a pattern sequence that is non-trivial.*
#     *   Sequence: 2, 3, 10, 15, 26, 35, 50... what is the next number? (Squares +/- 1). Too easy.
#
#     *   Let's try a "meta-puzzle".
#     *   "If a clock strikes thirteen, what time is it?" (Too much like a riddle).
#
#     *   Let's go for a high-difficulty logical reasoning problem.
#     *   "Three gods A, B, and C are called, in no particular order, True, False, and Random. True always speaks truly, False always speaks falsely, but whether Random speaks truly or falsely is a completely random matter. Your task is to determine the identities of A, B, and C by asking three yes-no questions; each question must be put to exactly one god. The gods understand English, but will answer all questions in their own language, in which the words for yes and no are 'da' and 'ja', in some order. You do not know which word means which. What three questions do you ask?"
#     *   (This is "The Hardest Logic Puzzle Ever").
#
#     *   Does it assess IQ (specifically logic, synthesis, and deduction)? Yes.
#     *   Is it hard/challenging? Yes.
#     *   Is the response *only* the question? Yes.</thought>Three gods A, B, and C are called, in no particular order, True, False, and Random. True always speaks truly, False always speaks falsely, but whether Random speaks truly or falsely is a completely random matter. Your task is to determine the identities of A, B, and C by asking three yes-no questions; each question must be put to exactly one god. The gods understand English, but will answer all questions in their own language, in which the words for yes and no are "da" and "ja", in some order. You do not know which word means which. What three questions do you ask?
#
# And here is a possible answer that might be correct or incorrect:
# Three gods A, B, and C are called, in no particular order, True, False, and Random. True always speaks truly, False always speaks falsely, but whether Random speaks truly or falsely is a completely random matter. Your task is to determine the identities of A, B, and C by asking three yes-no questions; each question must be put to exactly one god. The gods understand English, but will answer all questions in their own language, in which the words for yes and no are "da" and "ja", in some order. You do not know which word means which. What three questions do you ask?
#
# Please evaluate if the answer is correct or incorrect.

# %%
messages = [{"role": "user", "content": message}]
response = GoogleAI.chat.completions.create(model="gemma-4-31b-it", messages=messages)
print(response.choices[0].message.content)
# Out:
# <thought>*   The user provided a question (a logic puzzle known as "The Hardest Logic Puzzle Ever").
#     *   The user then provided an "answer."
#     *   The "answer" provided is an exact verbatim copy of the original question.
#     *   The goal is to evaluate if the answer is correct or incorrect.
#
#     *   Question: A complex logic puzzle requiring three specific questions to identify three gods (True, False, Random).
#     *   Answer: [The exact same text as the question].
#
#     *   Answering a question by repeating the question is not a solution.
#     *   The question asks "What three questions do you ask?"
#     *   The answer does not provide any questions; it simply repeats the prompt.
#
#     *   The answer is incorrect.</thought>The answer is **incorrect**.
#
# The provided answer is simply a verbatim repetition of the question itself. It does not provide the three questions required to solve the logic puzzle.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Something here"}]

# Then make the first call:

response =

# Then read the business idea:

business_area = response.

# And repeat! In the next message, include the business area within the message
